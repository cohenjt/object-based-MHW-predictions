# %%
import numpy as np
import xarray as xr

# %%
ds = xr.open_dataset('../final_data/spatial_attrs_r3.nc')

# %%
vars0 = ['CENTROID_DIST_KM', 'INTERSECTION_OVER_UNION']
vars1 = ['FCST_AREA', 'OBS_AREA']
vars2 = ['ABS_LOG_AREA_RATIO', 'ABS_LOG_INTENSITY_50_RATIO']

# %%
ds[vars0].to_netcdf('../final_data/spatial_attrs_r3_location.nc')
ds[vars2].to_netcdf('../final_data/spatial_attrs_r3_ratios.nc')
